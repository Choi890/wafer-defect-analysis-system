# %% [markdown]
# # 01 Data Exploration
#
# Load wafer map records, inspect label counts, and visualize samples.

# %%
from src.data.load_data import load_or_create_raw_dataset

df = load_or_create_raw_dataset()
df.head()

# %%
df['failure_type'].value_counts()
