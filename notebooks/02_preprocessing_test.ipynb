# %% [markdown]
# # 02 Preprocessing Test
#
# Generate train/test CSV files and label mappings.

# %%
from src.data.preprocess import preprocess_dataset

train_df, test_df = preprocess_dataset()
train_df.shape, test_df.shape

# %%
train_df.head()
